# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from feature_engine.encoding import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
survey_data = pd.read_csv('data_cleaned.csv')
print(survey_data.shape)

survey_data.head()
# Out:
# (792, 14)
#    gender mother_tongue mother_tongue_rating  no_of_fluent_languages  \
# 0  Female         Tamil            Excellent                     5.0
# 1    Male        Telugu            Excellent                     2.0
# 2  Female         Hindi                 Good                     1.0
# 3    Male        Telugu            Excellent                     3.0
# 4    Male       Kannada            Excellent                     3.0
#
#   educational_qualification           state  \
# 0             Undergraduate       Karnataka
# 1             Undergraduate  Andhra pradesh
# 2             Undergraduate   Uttar pradesh
# 3             Undergraduate       Telangana
# 4     After undergraduation       Karnataka
#
#   resided_in_the_same_city_from_birth teaching_language_preference  \
# 0                                 Yes            Regional Language
# 1                                 Yes             English Language
# 2                                  No              Hybrid Language
# 3                                 Yes              Hybrid Language
# 4                                 Yes              Hybrid Language
#
#   notes_language_preference questionpaper_language_preference  \
# 0         Regional Language                 Regional Language
# 1          English Language                  English Language
# 2          English Language                   Hybrid Language
# 3          English Language                  English Language
# 4          English Language                  English Language
#
#   learning_in_local_language exam_in_regional_language  \
# 0                        Yes                       Yes
# 1                      Maybe                        No
# 2                      Maybe                        No
# 3                        Yes                        No
# 4                        Yes                       Yes
#
#   teaching_in_regional_language knowledge_improvement
# 0                           Yes                   Yes
# 1                           Yes                   Yes
# 2                         Maybe                    No
# 3                           Yes                    No
# 4                           Yes                   Yes

# %%
null_features = [feature for feature in survey_data.columns if survey_data[feature].isnull().sum() > 0]

survey_data[null_features].isnull().sum().sort_values(ascending = False) * 100 / len(survey_data)
# Out:
# learning_in_local_language           6.439394
# no_of_fluent_languages               0.378788
# notes_language_preference            0.252525
# gender                               0.126263
# teaching_language_preference         0.126263
# questionpaper_language_preference    0.126263
# teaching_in_regional_language        0.126263
# dtype: float64

# %% [markdown]
# # The Variable Types

# %%
numerical_features = [feature for feature in survey_data.columns if survey_data[feature].dtype != 'O']
print("Total number of numerical features: ", len(numerical_features))
print(numerical_features)
# Out:
# Total number of numerical features:  1
# ['no_of_fluent_languages']

# %%
categorical_features = [feature for feature in survey_data.columns if feature not in numerical_features and feature != 'knowledge_improvement']
print("Total number of numerical features: ", len(categorical_features))
print(categorical_features)
# Out:
# Total number of numerical features:  12
# ['gender', 'mother_tongue', 'mother_tongue_rating', 'educational_qualification', 'state', 'resided_in_the_same_city_from_birth', 'teaching_language_preference', 'notes_language_preference', 'questionpaper_language_preference', 'learning_in_local_language', 'exam_in_regional_language', 'teaching_in_regional_language']

# %% [markdown]
# # Splitting train and test data

# %%
# 1. Removing null rows
survey_data = survey_data.dropna()

# %%
X_train, X_test, y_train, y_test = train_test_split(survey_data.drop(['knowledge_improvement'], axis = 1),
                                                                    survey_data['knowledge_improvement'],
                                                                    test_size = 0.3, random_state = 12)

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# # Categorical Encoding

# %%
print(survey_data.shape)
survey_data.head()
# Out:
# (734, 14)
#    gender mother_tongue mother_tongue_rating  no_of_fluent_languages  \
# 0  Female         Tamil            Excellent                     5.0
# 1    Male        Telugu            Excellent                     2.0
# 2  Female         Hindi                 Good                     1.0
# 3    Male        Telugu            Excellent                     3.0
# 4    Male       Kannada            Excellent                     3.0
#
#   educational_qualification           state  \
# 0             Undergraduate       Karnataka
# 1             Undergraduate  Andhra pradesh
# 2             Undergraduate   Uttar pradesh
# 3             Undergraduate       Telangana
# 4     After undergraduation       Karnataka
#
#   resided_in_the_same_city_from_birth teaching_language_preference  \
# 0                                 Yes            Regional Language
# 1                                 Yes             English Language
# 2                                  No              Hybrid Language
# 3                                 Yes              Hybrid Language
# 4                                 Yes              Hybrid Language
#
#   notes_language_preference questionpaper_language_preference  \
# 0         Regional Language                 Regional Language
# 1          English Language                  English Language
# 2          English Language                   Hybrid Language
# 3          English Language                  English Language
# 4          English Language                  English Language
#
#   learning_in_local_language exam_in_regional_language  \
# 0                        Yes                       Yes
# 1                      Maybe                        No
# 2                      Maybe                        No
# 3                        Yes                        No
# 4                        Yes                       Yes
#
#   teaching_in_regional_language knowledge_improvement
# 0                           Yes                   Yes
# 1                           Yes                   Yes
# 2                         Maybe                    No
# 3                           Yes                    No
# 4                           Yes                   Yes

# %% [markdown]
# ## Top 3 Mother tongue language

# %%
mother_tongue_encoder = OneHotEncoder(top_categories = 4, variables = ['mother_tongue'])
mother_tongue_encoder.fit(X_train)

X_train = mother_tongue_encoder.transform(X_train)
X_test = mother_tongue_encoder.transform(X_test)

# %%
categorical_features.remove('mother_tongue')

encoder = OneHotEncoder(variables = categorical_features)
encoder.fit(X_train)

X_train = encoder.transform(X_train)
X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#      no_of_fluent_languages  mother_tongue_Telugu  mother_tongue_Kannada  \
# 630                     4.0                     0                      0
# 545                     4.0                     0                      1
# 735                     4.0                     0                      1
# 459                     5.0                     0                      1
# 522                     2.0                     1                      0
#
#      mother_tongue_Tamil  mother_tongue_Hindi  gender_Male  gender_Female  \
# 630                    0                    0            1              0
# 545                    0                    0            0              1
# 735                    0                    0            1              0
# 459                    0                    0            1              0
# 522                    0                    0            1              0
#
#      gender_Prefer not to say  mother_tongue_rating_Excellent  \
# 630                         0                               1
# 545                         0                               0
# 735                         0                               0
# 459                         0                               1
# 522                         0                               1
#
#      mother_tongue_rating_Very Good  ...  \
# 630                               0  ...
# 545                               1  ...
# 735                               1  ...
# 459                               0  ...
# 522                               0  ...
#
#      questionpaper_language_preference_Regional Language  \
# 630                                                  0
# 545                                                  0
# 735                                                  0
# 459                                                  1
# 522                                                  0
#
#      learning_in_local_language_Yes  learning_in_local_language_No  \
# 630                               1                              0
# 545                               0                              1
# 735                               1                              0
# 459                               1                              0
# 522                               0                              0
#
#      learning_in_local_language_Maybe  exam_in_regional_language_No  \
# 630                                 0                             1
# 545                                 0                             0
# 735                                 0                             0
# 459                                 0                             0
# 522                                 1                             1
#
#      exam_in_regional_language_Yes  exam_in_regional_language_Maybe  \
# 630                              0                                0
# 545                              1                                0
# 735                              0                                1
# 459                              1                                0
# 522                              0                                0
#
#      teaching_in_regional_language_No  teaching_in_regional_language_Yes  \
# 630                                 1                                  0
# 545                                 0                                  1
# 735                                 0                                  0
# 459                                 0                                  1
# 522                                 1                                  0
#
#      teaching_in_regional_language_Maybe
# 630                                    0
# 545                                    0
# 735                                    1
# 459                                    0
# 522                                    0
#
# [5 rows x 44 columns]

# %% [markdown]
# # Feature Scaling

# %%
scaler = StandardScaler()
scaler.fit(X_train[numerical_features])

X_train[numerical_features] = scaler.transform(X_train[numerical_features])
X_test[numerical_features] = scaler.transform(X_test[numerical_features])

# %%
X_train.head()
# Out:
#      no_of_fluent_languages  mother_tongue_Telugu  mother_tongue_Kannada  \
# 630                0.797440                     0                      0
# 545                0.797440                     0                      1
# 735                0.797440                     0                      1
# 459                1.680996                     0                      1
# 522               -0.969673                     1                      0
#
#      mother_tongue_Tamil  mother_tongue_Hindi  gender_Male  gender_Female  \
# 630                    0                    0            1              0
# 545                    0                    0            0              1
# 735                    0                    0            1              0
# 459                    0                    0            1              0
# 522                    0                    0            1              0
#
#      gender_Prefer not to say  mother_tongue_rating_Excellent  \
# 630                         0                               1
# 545                         0                               0
# 735                         0                               0
# 459                         0                               1
# 522                         0                               1
#
#      mother_tongue_rating_Very Good  ...  \
# 630                               0  ...
# 545                               1  ...
# 735                               1  ...
# 459                               0  ...
# 522                               0  ...
#
#      questionpaper_language_preference_Regional Language  \
# 630                                                  0
# 545                                                  0
# 735                                                  0
# 459                                                  1
# 522                                                  0
#
#      learning_in_local_language_Yes  learning_in_local_language_No  \
# 630                               1                              0
# 545                               0                              1
# 735                               1                              0
# 459                               1                              0
# 522                               0                              0
#
#      learning_in_local_language_Maybe  exam_in_regional_language_No  \
# 630                                 0                             1
# 545                                 0                             0
# 735                                 0                             0
# 459                                 0                             0
# 522                                 1                             1
#
#      exam_in_regional_language_Yes  exam_in_regional_language_Maybe  \
# 630                              0                                0
# 545                              1                                0
# 735                              0                                1
# 459                              1                                0
# 522                              0                                0
#
#      teaching_in_regional_language_No  teaching_in_regional_language_Yes  \
# 630                                 1                                  0
# 545                                 0                                  1
# 735                                 0                                  0
# 459                                 0                                  1
# 522                                 1                                  0
#
#      teaching_in_regional_language_Maybe
# 630                                    0
# 545                                    0
# 735                                    1
# 459                                    0
# 522                                    0
#
# [5 rows x 44 columns]

# %% [markdown]
# # Saving our data

# %%
# Saving X_train and X_test
X_train.to_csv("X_train.csv", index = False)
X_test.to_csv("X_test.csv", index = False)

# %%
def encode_target(value):
    encode_dict = {'Yes': 1, 'No': 0, 'Maybe': 2}
    
    return encode_dict[value]

# %%
y_train = y_train.apply(encode_target)
y_test = y_test.apply(encode_target)

# %%
# Saving y_train and y_test
y_train.to_csv("y_train.csv", index = False)
y_test.to_csv("y_test.csv", index = False)
